# %% [markdown]
# # FPL Analytics
#
# Uncovering insights from the FPL API data. This notebook will explore the data and attempt to find interesting trends and patterns in the FPL game.

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data
elements_df = pd.read_csv(r'..\data\fromAPI\elements.csv')
teams_df = pd.read_csv(r'..\data\fromAPI\teams.csv')
elements_teams = pd.read_csv(r'..\data\fromAPI\elements_teams.csv')

# %% [markdown]
# ## Top Players by Total Points
#
# sort through all players, select top 20 by total points.
#
# This provides a snapshot of the best performing (FPL wise) players of the season.

# %%
# Get standard descriptive statistics for total points
elements_teams["total_points"].describe()
# Out:
# count    841.000000
# mean      40.882283
# std       50.303358
# min        0.000000
# 25%        0.000000
# 50%       14.000000
# 75%       74.000000
# max      239.000000
# Name: total_points, dtype: float64

# %%
# make a clean, defragmented copy of the DataFrame
elements_teams = elements_teams.copy()

# create a dictionary to translate element_type values into positions
position_map = {
    1: "GK",
    2: "DEF",
    3: "MID",
    4: "FWD"
}

# add position column
elements_teams["position"] = elements_teams["element_type"].map(position_map)

# add price column
elements_teams["price"] = elements_teams["now_cost"] / 10

# top 20 players by total points
elements_teams.sort_values("total_points", ascending=False)[
    ["web_name", "team_name", "position", "price", "total_points"]
].head(20)
# Out:
#         web_name      team_name position  price  total_points
# 525      Haaland       Man City      FWD   14.7           239
# 552  B.Fernandes        Man Utd      MID   10.4           235
# 4        Gabriel        Arsenal      DEF    7.3           209
# 495      Semenyo       Man City      MID    8.0           202
# 632  Gibbs-White  Nott'm Forest      MID    7.6           188
# 779        Bowen       West Ham      FWD    7.8           187
# 19          Rice        Arsenal      MID    7.2           184
# 209       Thiago      Brentford      FWD    7.2           181
# 634     Anderson  Nott'm Forest      MID    5.7           180
# 497        Guéhi       Man City      DEF    5.1           179
# 292   João Pedro        Chelsea      FWD    7.4           177
# 463       Virgil      Liverpool      DEF    6.1           175
# 135       Senesi    Bournemouth      DEF    5.2           175
# 355    Tarkowski        Everton      DEF    5.8           170
# 51        Rogers    Aston Villa      MID    7.3           169
# 400       Wilson         Fulham      MID    5.8           168
# 67       Watkins    Aston Villa      FWD    8.7           167
# 558     Casemiro        Man Utd      MID    5.8           165
# 137     Truffert    Bournemouth      DEF    4.8           165
# 0           Raya        Arsenal       GK    6.2           162
