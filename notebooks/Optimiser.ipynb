# %% [markdown]
# # Optimiser
#
# Create constraints to pick players for the team from the FPL rules.
#
# Rules:
#
# 1. Squad size: 15 players
# 2. Squad composition: 2 GKs, 5 DEFs, 5 MIDs, 3 FWDs
# 3. Bench composition: 1 GK, and leftover players not in starting XI
# 4. Minimum of 1 GK, 3 DEFs, 2 MIDs, 1 FWD in starting XI
# 3. Budget: £100.00m
# 4. No more than 3 players from the same club
# 5. Select captain and vice-captain from starting XI
# 6. Starting XI must be 11 players
# 7. Bench must be 4 players
# 8. Valid outfield formations: 3-4-3, 3-5-2, 4-4-2, 4-3-3, 5-4-1, 5-3-2
#
# Rules to ensure no errors:
#
# 1. Captain cannot be the same as vice-captain (and vice versa)
# 2. Bench must be lowest scoring players (or equal to the lowest scoring players) from the squad
# 3. starting XI players must not be bench players (and vice versa)

# %%
# imports
from pulp import *
