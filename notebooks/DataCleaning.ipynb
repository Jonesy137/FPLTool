# %% [markdown]
# # Data Cleaning
#
# Look at datatype and values of every column. Make amendments and check for correctness of the data. This is a crucial step before any analysis, as it ensures that the data is in the correct format and that there are no inconsistencies or errors that could affect the results of our analysis.

# %%
# imports
import pandas as pd

# %%
# load data
elements_teams = pd.read_csv(r'..\data\fromAPI\elements_teams.csv')

# print the datatype of each column
print(elements_teams.dtypes.to_string())
# Out:
# can_transact                               bool
# can_select                                 bool
# chance_of_playing_next_round            float64
# chance_of_playing_this_round            float64
# player_code                               int64
# cost_change_event                         int64
# cost_change_event_fall                    int64
# cost_change_start                         int64
# cost_change_start_fall                    int64
# price_change_percent                      int64
# dreamteam_count                           int64
# element_type                              int64
# ep_next                                 float64
# ep_this                                 float64
# event_points                              int64
# first_name                                  str
# player_form                             float64
# player_id                                 int64
# in_dreamteam                               bool
# news                                        str
# ...
